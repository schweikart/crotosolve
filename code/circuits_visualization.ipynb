# %%
import pennylane as qml
import pennylane.numpy as np

num_layers = 2 # 5
num_qubits = 5 # 4

# %% [markdown]
# ## Sim 01

# %%
from circuits import sim_01

qnode = sim_01(num_layers, num_qubits)
qml.draw_mpl(qnode)(
    np.array(np.random.random((num_layers, num_qubits, 2))),
    np.array([])
)
# Out:
# (<Figure size 900x600 with 1 Axes>, <Axes: >)

# %% [markdown]
# ## Sim 02

# %%
from circuits import sim_02

qnode = sim_02(num_layers, num_qubits)
qml.draw_mpl(qnode)(
    np.array(np.random.random((num_layers, num_qubits, 2))),
    np.array([])
)
# Out:
# (<Figure size 1700x600 with 1 Axes>, <Axes: >)

# %% [markdown]
# ## Sim 03

# %%
from circuits import sim_03

qnode = sim_03(num_layers, num_qubits)
qml.draw_mpl(qnode)(
    np.array(np.random.random((num_layers, num_qubits, 2))),
    np.array(np.random.random((num_layers, num_qubits - 1, 2)))
)
# Out:
# (<Figure size 1700x600 with 1 Axes>, <Axes: >)

# %% [markdown]
# ## Sim 04

# %%
from circuits import sim_04

qnode = sim_04(num_layers, num_qubits)
qml.draw_mpl(qnode)(
    np.array(np.random.random((num_layers, num_qubits, 2))),
    np.array(np.random.random((num_layers, num_qubits - 1, 2)))
)
# Out:
# (<Figure size 1700x600 with 1 Axes>, <Axes: >)

# %% [markdown]
# ## Sim 05

# %%
from circuits import sim_05

qnode = sim_05(num_layers, num_qubits)
qml.draw_mpl(qnode)(
    np.array(np.random.random((num_layers, num_qubits, 4))),
    np.array(np.random.random((num_layers, num_qubits, num_qubits - 1)))
)
# Out:
# (<Figure size 5300x600 with 1 Axes>, <Axes: >)

# %% [markdown]
# ## Sim 06

# %%
from circuits import sim_06

qnode = sim_06(num_layers, num_qubits)
qml.draw_mpl(qnode)(
    np.array(np.random.random((num_layers, num_qubits, 4))),
    np.array(np.random.random((num_layers, num_qubits, num_qubits - 1)))
)
# Out:
# (<Figure size 5300x600 with 1 Axes>, <Axes: >)

# %% [markdown]
# ## Sim 07

# %%
from circuits import sim_07

qnode = sim_07(num_layers, num_qubits)
qml.draw_mpl(qnode)(
    np.array(np.random.random((num_layers, num_qubits, 4))),
    np.array(np.random.random((num_layers, num_qubits - 1)))
)
# Out:
# (<Figure size 1700x600 with 1 Axes>, <Axes: >)

# %% [markdown]
# ## Sim 08

# %%
from circuits import sim_08

qnode = sim_08(num_layers, num_qubits)
qml.draw_mpl(qnode)(
    np.array(np.random.random((num_layers, num_qubits, 4))),
    np.array(np.random.random((num_layers, num_qubits - 1)))
)
# Out:
# (<Figure size 1700x600 with 1 Axes>, <Axes: >)

# %% [markdown]
# ## Sim 09

# %%
from circuits import sim_09

qnode = sim_09(num_layers, num_qubits)
qml.draw_mpl(qnode)(
    np.array(np.random.random((num_layers, num_qubits))),
    np.array([])
)
# Out:
# (<Figure size 1700x600 with 1 Axes>, <Axes: >)

# %% [markdown]
# ## Sim 10

# %%
from circuits import sim_10

qnode = sim_10(num_layers, num_qubits)
qml.draw_mpl(qnode)(
    np.array(np.random.random((num_layers + 1, num_qubits))),
    np.array([])
)
# Out:
# (<Figure size 1800x600 with 1 Axes>, <Axes: >)

# %% [markdown]
# ## Sim 11

# %%
from circuits import sim_11

qnode = sim_11(num_layers)
qml.draw_mpl(qnode)(
    np.array(np.random.random((num_layers, num_qubits, 3))),
    np.array([])
)
# Out:
# (<Figure size 1700x500 with 1 Axes>, <Axes: >)

# %% [markdown]
# ## Sim 12

# %%
from circuits import sim_12

qnode = sim_12(num_layers)
qml.draw_mpl(qnode)(
    np.array(np.random.random((num_layers, num_qubits, 3))),
    np.array([])
)
# Out:
# (<Figure size 1700x500 with 1 Axes>, <Axes: >)

# %% [markdown]
# ## Sim 13

# %%
from circuits import sim_13

qnode = sim_13(num_layers, num_qubits)
qml.draw_mpl(qnode)(
    np.array(np.random.random((num_layers, num_qubits, 2))),
    np.array(np.random.random((num_layers, num_qubits, 2)))
)
# Out:
# (<Figure size 2700x600 with 1 Axes>, <Axes: >)

# %% [markdown]
# ## Sim 14

# %%
from circuits import sim_14

qnode = sim_14(num_layers, num_qubits)
qml.draw_mpl(qnode)(
    np.array(np.random.random((num_layers, num_qubits, 2))),
    np.array(np.random.random((num_layers, num_qubits, 2)))
)
# Out:
# (<Figure size 2700x600 with 1 Axes>, <Axes: >)

# %% [markdown]
# ## Sim 15

# %%
from circuits import sim_15

qnode = sim_15(num_layers, num_qubits)
qml.draw_mpl(qnode)(
    np.array(np.random.random((num_layers, num_qubits, 2))),
    np.array([])
)
# Out:
# (<Figure size 2700x600 with 1 Axes>, <Axes: >)

# %% [markdown]
# ## Sim 16

# %%
from circuits import sim_16

qnode = sim_16(num_layers, num_qubits)
qml.draw_mpl(qnode)(
    np.array(np.random.random((num_layers, num_qubits, 2))),
    np.array(np.random.random((num_layers, num_qubits - 1)))
)
# Out:
# (<Figure size 1300x600 with 1 Axes>, <Axes: >)

# %% [markdown]
# ## Sim 17

# %%
from circuits import sim_17

qnode = sim_17(num_layers, num_qubits)
qml.draw_mpl(qnode)(
    np.array(np.random.random((num_layers, num_qubits, 2))),
    np.array(np.random.random((num_layers, num_qubits - 1)))
)
# Out:
# (<Figure size 1300x600 with 1 Axes>, <Axes: >)

# %% [markdown]
# ## Sim 18

# %%
from circuits import sim_18

qnode = sim_18(num_layers, num_qubits)
qml.draw_mpl(qnode)(
    np.array(np.random.random((num_layers, num_qubits, 2))),
    np.array(np.random.random((num_layers, num_qubits)))
)
# Out:
# (<Figure size 1900x600 with 1 Axes>, <Axes: >)

# %% [markdown]
# ## Sim 19

# %%
from circuits import sim_19

qnode = sim_19(num_layers, num_qubits)
qml.draw_mpl(qnode)(
    np.array(np.random.random((num_layers, num_qubits, 2))),
    np.array(np.random.random((num_layers, num_qubits)))
)
# Out:
# (<Figure size 1900x600 with 1 Axes>, <Axes: >)
